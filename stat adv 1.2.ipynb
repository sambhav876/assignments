# %%
#question 1

#The PMF is a function that gives the probability of a discrete random variable taking on a specific value.
#The PDF is a function that describes the likelihood of a continuous random variable falling within a particular range of values.

#example

#PMF example: Rolling a die and finding the probability of getting a specific number and PDF example: Describing the probability distribution of heights in a population.

# %%
#question 2

#The Cumulative Distribution Function (CDF) is a concept in probability theory and statistics that provides the probability that a random variable takes on a value less than or equal to a specified point
# example is six sided die
#uses : he CDF provides cumulative information about the distribution, allowing you to determine the probability of a random variable being less than or equal to a specific value.

# %%
#question 3

#he normal distribution, also known as the Gaussian distribution or bell curve, is widely used in various fields to model the distribution of random variables. Here are some examples of situations where the normal distribution might be used as a model:

Biological Measurements:

Example: Heights or weights of a population.
Explanation: Human height and weight often follow a normal distribution, making it a suitable model for these biological measurements.
Educational Testing:

Example: SAT scores or IQ scores.
Explanation: Test scores, when properly standardized, often exhibit a normal distribution, helping in the analysis and interpretation of results.
Financial Markets:

Example: Daily stock returns.
Explanation: Stock returns are often assumed to follow a normal distribution in financial modeling, particularly when calculating risk measures.
Quality Control:

Example: Measurement errors in manufacturing.
Explanation: The normal distribution is commonly used to model random errors in measurements and manufacturing processes.
Physical Sciences:

Example: Measurement errors in laboratory experiments.
Explanation: Experimental errors and uncertainties are often modeled using a normal distribution.
Psychological Testing:

Example: Personality test scores.
Explanation: Psychological traits are often assumed to be normally distributed in the population.
Demographics:

Example: Population ages or income levels.
Explanation: Age distribution or income distribution in a population may be approximated by a normal distribution.
Parameters of the Normal Distribution:
The normal distribution is characterized by two parameters: the mean (
�
μ) and the standard deviation (
�
σ). These parameters dictate the shape and characteristics of the distribution.

Mean (
�
μ):

Determines the central location of the distribution.
Shifts the entire distribution left or right along the x-axis.
A larger mean shifts the distribution to the right, and a smaller mean shifts it to the left.
Standard Deviation (
�
σ):

Controls the spread or dispersion of the distribution.
A larger standard deviation results in a wider and flatter distribution.
A smaller standard deviation results in a narrower and taller distribution.
The probability density function (PDF) of the normal distribution is given by:
�
(
�
)
=
1
2
�
�
2
exp
⁡
(
−
(
�
−
�
)
2
2
�
2
)
f(x)= 
2πσ 
2
 
​
 
1
​
 exp(− 
2σ 
2
 
(x−μ) 
2
 
​
 )

In summary, the normal distribution is versatile and is often used as a model in situations where the data exhibit a symmetric, bell-shaped pattern. The mean and standard deviation parameters play crucial roles in shaping the distribution and determining its characteristics.

# %%
#question 4

#The normal distribution's ubiquity in various aspects of real-world data makes it a valuable tool for understanding, analyzing, and making predictions in a wide range of disciplines.
#examples: height data, blood pressure, IQ scores.

# %%
#question 5

#The Bernoulli distribution is a discrete probability distribution that models a random experiment with two possible outcomes: success (usually denoted as 1) and failure (usually denoted as 0). It is named after the Swiss mathematician Jacob Bernoulli. 
#Bernoulli Distribution: Describes a single trial or experiment with two possible outcomes (success or failure).Binomial Distribution: Describes the number of successes in a fixed number of independent and identically distributed Bernoulli trials.

# %%
#question 7

# uniform distribution is a probability distribution where all outcomes are equally likely. In a continuous uniform distribution, all values within a specified range are equally likely, while in a discrete uniform distribution, each outcome has the same probability of occurring.
#uppose we have a spinner with values 1 to 6, inclusive, and each value is equally likely to occur when the spinner is spun. The spinner follows a discrete uniform distribution.

#properties : equal probability, CDF, PDF, means , variance

# %%
#question 8

#The z-score, also known as the standard score or z-value, is a measure of how many standard deviations a particular data point is from the mean of a distribution.
